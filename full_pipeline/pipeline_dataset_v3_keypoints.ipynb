# %% [markdown]
# ## 1. load the model face_detection
# Step 1 is the same for each pipeline, so we do it once at the beginning.

# %% [markdown]
# **Import dependencies**

# %%
# %load_ext autoreload
# %autoreload 2

from libraries.embeddings_utils import *
import ipynbname
from libraries.retrieval_utils import *
from libraries.classifier_utils import *
from libraries.file_manager_utils import *

project_dir = f"{os.getcwd().split('SIDS_revelation_project')[0]}SIDS_revelation_project/"
image_dataset_path = f"{project_dir}datasets/onback_onstomach_v3"
model_path_fd = f"{project_dir}/models/4.fd_weights/best.pt"
model_path_pe = f"{project_dir}/models/1.pe_weights/best.pt"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Choose how to process the dataset:**
# 1. "extract_features":                     extracting features and labels
# 2. "extract_features_imageswithinference": extracting features and labels and saving predicted images with bboxes
# 3. "load":                                  loading features and labels

# %%
emb_builder = EmbeddingBuilder(model_path_fd, image_dataset_path, "extract_features",weights_path_pe=model_path_pe)
# Out:
# Extracting dataset info from .coco.json file:---------------------------------------------
# Dataset contains 4158 valid samples, and labels are {'baby_on_back': 1, 'baby_on_stomach': 2}
# ------------------------------------------------------------------------------------------
#
# Feature extraction for each dataset image-------------------------------------------------
# 0%-->    0 / 4158 files processed
# 2%-->    100 / 4158 files processed
# 4%-->    200 / 4158 files processed
# 7%-->    300 / 4158 files processed
# 9%-->    400 / 4158 files processed
# 12%-->    500 / 4158 files processed
# 14%-->    600 / 4158 files processed
# 16%-->    700 / 4158 files processed
# 19%-->    800 / 4158 files processed
# 21%-->    900 / 4158 files processed
# 24%-->    1000 / 4158 files processed
# 26%-->    1100 / 4158 files processed
# 28%-->    1200 / 4158 files processed
# 31%-->    1300 / 4158 files processed
# 33%-->    1400 / 4158 files processed
# 36%-->    1500 / 4158 files processed
# 38%-->    1600 / 4158 files processed
# 40%-->    1700 / 4158 files processed
# 43%-->    1800 / 4158 files processed
# 45%-->    1900 / 4158 files processed
# 48%-->    2000 / 4158 files processed
# 50%-->    2100 / 4158 files processed
# 52%-->    2200 / 4158 files processed
# 55%-->    2300 / 4158 files processed
# 57%-->    2400 / 4158 files processed
# 60%-->    2500 / 4158 files processed
# 62%-->    2600 / 4158 files processed
# 64%-->    2700 / 4158 files processed
# 67%-->    2800 / 4158 files processed
# 69%-->    2900 / 4158 files processed
# 72%-->    3000 / 4158 files processed
# 74%-->    3100 / 4158 files processed
# 76%-->    3200 / 4158 files processed
# 79%-->    3300 / 4158 files processed
# 81%-->    3400 / 4158 files processed
# 84%-->    3500 / 4158 files processed
# 86%-->    3600 / 4158 files processed
# 88%-->    3700 / 4158 files processed
# 91%-->    3800 / 4158 files processed
# 93%-->    3900 / 4158 files processed
# 96%-->    4000 / 4158 files processed
# 98%-->    4100 / 4158 files processed
# 4158 image processed, features(self.features) and labels(self.y) extracted
# ------------------------------------------------------------------------------------------
#
# Saving features in .csv
# Dataframe with columns [eye1, eye2, nose, mouth, head, label, image_path]. [eye1, eye2, mouth, label, head] are equal to (-1, -1) if were not detected:
# Features saved in '/home/terra/Desktop/unimore/AI_engineering/SIDS_revelation_project/datasets/onback_onstomach_v3/model4_features_keypoints.csv'
# ------------------------------------------------------------------------------------------
#
# Embedding builder initialized successfully------------------------------------------------
# Face detection model: 4 (YOLOv8)
# Dataset: /home/terra/Desktop/unimore/AI_engineering/SIDS_revelation_project/datasets/onback_onstomach_v3
# Dataset dimension: 4158
# Dataset labels: {'baby_safe': 0, 'baby_unsafe': 1}
# ------------------------------------------------------------------------------------------

# %%
emb_builder.features.head()
# Out:
#                                       nose_k  \
# 0   (0.5038059949874878, 0.5425757765769958)
# 1  (0.35188406705856323, 0.7374834418296814)
# 2   (0.8038495182991028, 0.5994570255279541)
# 3                                   (-1, -1)
# 4  (0.6223902702331543, 0.11976964771747589)
#
#                                   left_eye_k  \
# 0    (0.548958420753479, 0.5166415572166443)
# 1  (0.33699801564216614, 0.6948834657669067)
# 2   (0.8373699188232422, 0.5690237879753113)
# 3                                   (-1, -1)
# 4  (0.6355379223823547, 0.09885656833648682)
#
#                                  right_eye_k  \
# 0   (0.5290319919586182, 0.5230056643486023)
# 1   (0.3208518922328949, 0.7431143522262573)
# 2   (0.8244951367378235, 0.6541568636894226)
# 3                                   (-1, -1)
# 4  (0.6682705283164978, 0.10321386158466339)
#
#                                     left_ear  \
# 0   (0.5766869187355042, 0.5057727694511414)
# 1    (0.3736308217048645, 0.593382716178894)
# 2  (0.8388290405273438, 0.47255510091781616)
# 3                                   (-1, -1)
# 4  (0.6643956899642944, 0.14939293265342712)
#
#                                    right_ear  \
# 0    (0.5177388191223145, 0.515906035900116)
# 1   (0.3252469599246979, 0.7227302193641663)
# 2   (0.8194858431816101, 0.7613769769668579)
# 3                                   (-1, -1)
# 4  (0.7685152888298035, 0.15619032084941864)
#
#                                left_shoulder  \
# 0  (0.4886975884437561, 0.49852555990219116)
# 1   (0.4698246121406555, 0.5646583437919617)
# 2   (0.722925066947937, 0.42533499002456665)
# 3                                   (-1, -1)
# 4  (0.6756753921508789, 0.24900731444358826)
#
#                               right_shoulder  \
# 0  (0.40118083357810974, 0.5993157029151917)
# 1   (0.4295632839202881, 0.7476526498794556)
# 2   (0.6848393678665161, 0.7516647577285767)
# 3                                   (-1, -1)
# 4    (0.755947470664978, 0.2668847143650055)
#
#                                   left_elbow  \
# 0   (0.4656759798526764, 0.6535560488700867)
# 1   (0.5279341340065002, 0.5232251882553101)
# 2   (0.6916258931159973, 0.1871720850467682)
# 3                                   (-1, -1)
# 4  (0.49630850553512573, 0.3740745484828949)
#
#                                 right_elbow  \
# 0  (0.3222746253013611, 0.7711942791938782)
# 1  (0.4485192894935608, 0.8584781885147095)
# 2  (0.6367122530937195, 0.8371478915214539)
# 3                                  (-1, -1)
# 4  (0.7155963182449341, 0.4258364737033844)
#
#                                   left_wrist  ...  \
# 0   (0.4659738540649414, 0.7164319753646851)  ...
# 1   (0.4531176686286926, 0.4978567957878113)  ...
# 2  (0.7675493359565735, 0.11681647598743439)  ...
# 3                                   (-1, -1)  ...
# 4  (0.38994598388671875, 0.4899890422821045)  ...
#
#                                  right_knee  \
# 0                                  (-1, -1)
# 1    (0.68714439868927, 0.9617096185684204)
# 2   (0.2484249770641327, 0.723051905632019)
# 3                                  (-1, -1)
# 4  (0.5368216037750244, 0.7558255195617676)
#
#                                    left_ankle  \
# 0                                    (-1, -1)
# 1    (0.8127692341804504, 0.7001568078994751)
# 2  (0.17542067170143127, 0.39759618043899536)
# 3                                    (-1, -1)
# 4    (0.4050411283969879, 0.8676735758781433)
#
#                                  right_ankle  \
# 0                                   (-1, -1)
# 1    (0.8025773763656616, 0.931956946849823)
# 2  (0.10704417526721954, 0.5807881355285645)
# 3                                   (-1, -1)
# 4  (0.43817782402038574, 0.9184666872024536)
#
#                                        eye1  \
# 0                                  (-1, -1)
# 1                                  (-1, -1)
# 2  (0.8405969738960266, 0.6708656549453735)
# 3                                  (-1, -1)
# 4                                  (-1, -1)
#
#                                        eye2  \
# 0                                  (-1, -1)
# 1                                  (-1, -1)
# 2  (0.8511886596679688, 0.5541306734085083)
# 3                                  (-1, -1)
# 4                                  (-1, -1)
#
#                                       nose  \
# 0                                 (-1, -1)
# 1                                 (-1, -1)
# 2  (0.822311282157898, 0.6106249094009399)
# 3                                 (-1, -1)
# 4                                 (-1, -1)
#
#                                       mouth  \
# 0                                  (-1, -1)
# 1                                  (-1, -1)
# 2  (0.7827173471450806, 0.6056033968925476)
# 3                                  (-1, -1)
# 4                                  (-1, -1)
#
#                                                 head  \
# 0  (0.406229168176651, 0.49659210443496704, 0.447...
# 1  (0.3316466808319092, 0.5991604924201965, 0.157...
# 2  (0.8718616366386414, 0.6115387678146362, 0.248...
# 3  (0.5774679780006409, 0.11800871044397354, 0.43...
# 4  (0.7344851493835449, 0.129198357462883, 0.3624...
#
#                                           image_path label
# 0  Sideways_89_jpg.rf.a6f56a333a91ad3618c02ae3c21...     0
# 1  Cubo_05_JPG_jpg.rf.d1de2c4a1111a2e4bf158ee897f...     1
# 2  baby44_jpg.rf.f0f2dd958eb0b2a0b85c3d60b21e3e69...     0
# 3  Nanit_39_JPG_jpg.rf.3d42ac5690cf29d28f0918d5d9...     1
# 4  2363_png_jpg.rf.26b24e23c084073a7c98b607a8430a...     1
#
# [5 rows x 24 columns]
